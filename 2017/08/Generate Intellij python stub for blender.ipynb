# %% [markdown]
# ## run

# %%
# %%script zsh
# temp_dir=`mktemp -d`
# cd $temp_dir
# git clone https://github.com/peace0phmind/pycharm-blender.git
# cd pycharm-blender/python_api
# /Users/mind/Applications/blender.app/Contents/MacOS/blender -b -P pypredef_gen.py
# cp -R pypredef /Users/mind/Applications/blender.app/Contents/Resources/2.78/blender_stub
# rm -rf $temp_dir
# Out:
# Missing argument declaration for 'flag'
# class Action:
#
# class ActionActuator:
#
# class ActionConstraint:
#
# class ActionFCurves:
#
# class ActionGroup:
#
# class ActionGroups:
#
# class ActionPoseMarkers:
#
# class Actuator:
#
# class ActuatorSensor:
#
# class AddSequence:
#
# class Addon:
#
# class AddonPreferences:
#
# class Addons:
#
# class AdjustmentSequence:
#
# class AlembicObjectPath:
#
# class AlembicObjectPaths:
#
# class AlphaOverSequence:
#
# class AlphaUnderSequence:
#
# class AlwaysSensor:
#
# class AndController:
#
# class AnimData:
#
# class AnimDataDrivers:
#
# class AnimViz:
#
# class AnimVizMotionPaths:
#
# class AnimVizOnionSkinning:
#
# class AnyType:
#
# class Area:
#
# class AreaLamp:
#
# class AreaSpaces:
#
# class Armature:
#
# class ArmatureActuator:
#
# class ArmatureBones:
#
# class ArmatureEditBones:
#
# class ArmatureModifier:
#
# class ArmatureSensor:
#
# class ArrayModifier:
#
# class Available:
#
# class BackgroundImage:
#
# ...

# %% [markdown]
# ## add path /Users/mind/Applications/blender.app/Contents/Resources/2.78/blender_stub into intellij python SDK classpath
